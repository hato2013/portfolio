# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_rows', 100)

# %%
types_dict_train = {'train_id':'int64', 'item_condition_id':'int8', 'price':'float64', 'shipping':'int8'}
types_dict_test = {'test_id':'int64', 'item_condition_id':'int8', 'shipping':'int8'}
 
# tsvファイルからPandas DataFrameへ読み込み
train_df = pd.read_csv('train.tsv', delimiter='\t', low_memory=True, dtype=types_dict_train)
test_df = pd.read_csv('test_stg2.tsv', delimiter='\t', low_memory=True, dtype=types_dict_test)

# %%
all_df = pd.concat([train_df,test_df],sort=False).reset_index(drop=True)

# %%
train_df[:100]
# Out:
#     train_id                                      name  item_condition_id  \
# 0          0       MLB Cincinnati Reds T Shirt Size XL                  3
# 1          1          Razer BlackWidow Chroma Keyboard                  3
# 2          2                            AVA-VIV Blouse                  1
# 3          3                     Leather Horse Statues                  1
# 4          4                      24K GOLD plated rose                  1
# 5          5          Bundled items requested for Ruie                  3
# 6          6        Acacia pacific tides santorini top                  3
# 7          7      Girls cheer and tumbling bundle of 7                  3
# 8          8                     Girls Nike Pro shorts                  3
# 9          9    Porcelain clown doll checker pants VTG                  3
# 10        10                           Smashbox primer                  2
# 11        11                    New vs pi k body mists                  1
# ...

# %%
all_df[all_df["price"]>100][:100]
# Out:
#       train_id                                      name  item_condition_id  \
# 22        22.0            Galaxy S7 Edge (Unlocked) 32GB                  3
# 36        36.0                              Black bag 30                  3
# 38        38.0                                  XBOX One                  3
# 50        50.0                    Michael Kors CrossBody                  2
# 60        60.0           1/4 ct Diamond Engagement Ring!                  3
# 94        94.0                        Hatchimals Draggle                  1
# 145      145.0                   Air Jordan 1 Breds 2016                  1
# 149      149.0                        LIKE NEW IPHONE 5C                  2
# 150      150.0     Kate spade mylie black hobo crossbody                  1
# 157      157.0              Opi polish Hold for Chi Thuy                  1
# 216      216.0       YSL OTL BDJ Chevrette 2A Clutch NEW                  2
# ...

# %%
all_df.sort_values('price')[:100]
# Out:
#           train_id                                      name  \
# 1079043  1079043.0                      Modern + Pillow New!
# 644432    644432.0        Hawaiian Blue leggings in One Size
# 461372    461372.0                  Lululemon lavender skort
# 788994    788994.0  PEACOCK FEATHERS 3M POPSOCKET PHONE GRIP
# 996618    996618.0          Jordan's Authentic Toddler Shoes
# 1378634  1378634.0                 AP Biology 450 Flashcards
# 729771    729771.0              Handmade Bronze Eye Earrings
# 921821    921821.0         Twisted Peppermint 3 wick candles
# 915093    915093.0                         Frozen Elsa Dress
# 1446187  1446187.0    Handcrafted Jadeite Frogs and Crystals
# 137980    137980.0         Harley Davidson Motorcycle Jacket
# 416060    416060.0                      LuLaRoe medium Randy
# 1332074  1332074.0                     On fleek Rae Dunn mug
# 937578    937578.0               Givenchy Crossbody / Clutch
# ...

# %%
chanel_list = all_df['brand_name'].str.contains('Chanel',na=False)

# %%
all_df[chanel_list].describe()
# Out:
#            train_id  item_condition_id        price     shipping       test_id
# count  2.353000e+03        7947.000000  2353.000000  7947.000000  5.594000e+03
# mean   7.350703e+05           1.874670    74.770081     0.424563  1.729127e+06
# std    4.332986e+05           0.935039   173.027342     0.494308  9.910861e+05
# min    5.680000e+02           1.000000     3.000000     0.000000  1.340000e+02
# 25%    3.538920e+05           1.000000    20.000000     0.000000  8.763010e+05
# 50%    7.299190e+05           2.000000    35.000000     0.000000  1.718939e+06
# 75%    1.106761e+06           3.000000    64.000000     1.000000  2.597848e+06
# max    1.482112e+06           5.000000  2009.000000     1.000000  3.460287e+06

# %%
david_list = all_df['brand_name'].str.contains('David Yurman',na=False)

# %%
all_df[david_list].describe()
# Out:
#            train_id  item_condition_id        price    shipping       test_id
# count  2.420000e+02         794.000000   242.000000  794.000000  5.520000e+02
# mean   7.466539e+05           2.133501   248.611570    0.591940  1.720270e+06
# std    4.266694e+05           0.568009   190.054736    0.491784  1.002025e+06
# min    2.689000e+03           1.000000     7.000000    0.000000  1.538900e+04
# 25%    3.855250e+05           2.000000   170.000000    0.000000  8.156332e+05
# 50%    7.624645e+05           2.000000   220.000000    1.000000  1.693632e+06
# 75%    1.111340e+06           2.000000   300.000000    1.000000  2.613367e+06
# max    1.477328e+06           4.000000  2004.000000    1.000000  3.460456e+06

# %%
mary_list = all_df['brand_name'].str.contains('Mary Kay',na=False)

# %%
all_df[mary_list].describe()
# Out:
#            train_id  item_condition_id        price     shipping       test_id
# count  2.537000e+03        8319.000000  2537.000000  8319.000000  5.782000e+03
# mean   7.574095e+05           1.230557    18.216397     0.568338  1.716329e+06
# std    4.274985e+05           0.541141    45.921137     0.495338  9.972724e+05
# min    6.900000e+02           1.000000     3.000000     0.000000  5.470000e+02
# 25%    3.987280e+05           1.000000     9.000000     0.000000  8.422612e+05
# 50%    7.540780e+05           1.000000    12.000000     1.000000  1.724662e+06
# 75%    1.131130e+06           1.000000    19.000000     1.000000  2.579374e+06
# max    1.482480e+06           4.000000  2000.000000     1.000000  3.460253e+06

# %%
apple_list = all_df['brand_name'].str.contains('Apple',na=False)

# %%
all_df[apple_list].describe()
# Out:
#            train_id  item_condition_id         price      shipping  \
# count  1.735800e+04       57844.000000  17358.000000  57844.000000
# mean   7.421092e+05           2.091557     73.270250      0.527972
# std    4.292483e+05           1.090823    119.799013      0.499221
# min    2.600000e+01           1.000000      0.000000      0.000000
# 25%    3.677415e+05           1.000000     11.000000      0.000000
# 50%    7.392905e+05           2.000000     22.000000      1.000000
# 75%    1.116749e+06           3.000000     86.000000      1.000000
# max    1.482499e+06           5.000000   1909.000000      1.000000
#
#             test_id
# count  4.048600e+04
# mean   1.725660e+06
# std    1.000542e+06
# min    2.100000e+01
# 25%    8.585230e+05
# 50%    1.720848e+06
# 75%    2.593355e+06
# max    3.460631e+06

# %%
louis_list = all_df['brand_name'].str.contains('Louis Vuitton',na=False)

# %%
all_df[louis_list].describe()
# Out:
#            train_id  item_condition_id        price      shipping  \
# count  3.187000e+03       10815.000000  3187.000000  10815.000000
# mean   7.478540e+05           2.535368   202.187637      0.360518
# std    4.261957e+05           0.938275   247.801644      0.480173
# min    7.660000e+02           1.000000     3.000000      0.000000
# 25%    3.875970e+05           2.000000    41.000000      0.000000
# 50%    7.522930e+05           3.000000   106.000000      0.000000
# 75%    1.118897e+06           3.000000   264.000000      1.000000
# max    1.481847e+06           5.000000  1815.000000      1.000000
#
#             test_id
# count  7.628000e+03
# mean   1.720171e+06
# std    9.950694e+05
# min    2.380000e+02
# 25%    8.687380e+05
# 50%    1.722024e+06
# 75%    2.584426e+06
# max    3.460127e+06

# %%
all_df[celine_list].describe()
# Out:
#            train_id  item_condition_id        price    shipping       test_id
# count  7.300000e+01          261.00000    73.000000  261.000000  1.880000e+02
# mean   6.982928e+05            2.13410   238.780822    0.406130  1.667204e+06
# std    4.222431e+05            0.76033   339.356795    0.492053  9.524306e+05
# min    2.569000e+03            1.00000    12.000000    0.000000  1.633000e+03
# 25%    3.522430e+05            2.00000    65.000000    0.000000  8.335275e+05
# 50%    6.497200e+05            2.00000   149.000000    0.000000  1.704366e+06
# 75%    1.000120e+06            3.00000   239.000000    1.000000  2.412626e+06
# max    1.465701e+06            4.00000  1806.000000    1.000000  3.452649e+06

# %%
celine_list = all_df['brand_name'].str.contains('Celine',na=False)

# %%
bag_list = all_df['category_name'].str.contains('Handbags|Shoulder Bag',na=False)
bag2_list = all_df['category_name'].str.contains('Shoulder Bag',na=False)

# %%
shoes_list = all_df['category_name'].str.contains('Shoes',na=False)

# %%
coats_list = all_df['category_name'].str.contains('Coats',na=False)

# %%
beauty_list = all_df['category_name'].str.contains('Beauty',na=False)

# %%
2.673752e+01
# Out:
# 26.73752

# %%
all_df[shoes_list].describe()
# Out:
#            train_id  item_condition_id          price       shipping  \
# count  1.326430e+05      441144.000000  132643.000000  441144.000000
# mean   7.424743e+05           2.374279      37.682543       0.269021
# std    4.276506e+05           0.894930      39.778706       0.443451
# min    1.400000e+01           1.000000       0.000000       0.000000
# 25%    3.727570e+05           2.000000      16.000000       0.000000
# 50%    7.424230e+05           3.000000      26.000000       0.000000
# 75%    1.114284e+06           3.000000      44.000000       1.000000
# max    1.482482e+06           5.000000     950.000000       1.000000
#
#             test_id
# count  3.085010e+05
# mean   1.731341e+06
# std    9.992446e+05
# min    2.400000e+01
# 25%    8.651330e+05
# 50%    1.729440e+06
# 75%    2.596929e+06
# max    3.460723e+06

# %%
all_df[coats_list].describe()
# Out:
#            train_id  item_condition_id         price      shipping  \
# count  2.551100e+04       84610.000000  25511.000000  84610.000000
# mean   7.421449e+05           2.337301     29.898201      0.289162
# std    4.282753e+05           0.773003     28.792495      0.453376
# min    4.500000e+01           1.000000      0.000000      0.000000
# 25%    3.708400e+05           2.000000     14.000000      0.000000
# 50%    7.434820e+05           2.000000     22.000000      0.000000
# 75%    1.111673e+06           3.000000     36.000000      1.000000
# max    1.482505e+06           5.000000   1009.000000      1.000000
#
#             test_id
# count  5.909900e+04
# mean   1.729455e+06
# std    9.989359e+05
# min    1.700000e+01
# 25%    8.625360e+05
# 50%    1.728641e+06
# 75%    2.596010e+06
# max    3.460724e+06

# %%
all_df[beauty_list].describe()
# Out:
#            train_id  item_condition_id          price       shipping  \
# count  2.078280e+05      692999.000000  207828.000000  692999.000000
# mean   7.401276e+05           1.416348      19.671536       0.611542
# std    4.277715e+05           0.735096      21.360135       0.487400
# min    1.000000e+01           1.000000       0.000000       0.000000
# 25%    3.695545e+05           1.000000      10.000000       0.000000
# 50%    7.391305e+05           1.000000      15.000000       1.000000
# 75%    1.109862e+06           2.000000      24.000000       1.000000
# max    1.482523e+06           5.000000    2000.000000       1.000000
#
#             test_id
# count  4.851710e+05
# mean   1.729400e+06
# std    9.990399e+05
# min    8.000000e+00
# 25%    8.651555e+05
# 50%    1.727781e+06
# 75%    2.595767e+06
# max    3.460720e+06

# %%
all_df.describe()
# Out:
#            train_id  item_condition_id         price      shipping  \
# count  1.482535e+06       4.943260e+06  1.482535e+06  4.943260e+06
# mean   7.412670e+05       1.907122e+00  2.673752e+01  4.475771e-01
# std    4.279711e+05       9.035150e-01  3.858607e+01  4.972443e-01
# min    0.000000e+00       1.000000e+00  0.000000e+00  0.000000e+00
# 25%    3.706335e+05       1.000000e+00  1.000000e+01  0.000000e+00
# 50%    7.412670e+05       2.000000e+00  1.700000e+01  0.000000e+00
# 75%    1.111900e+06       3.000000e+00  2.900000e+01  1.000000e+00
# max    1.482534e+06       5.000000e+00  2.009000e+03  1.000000e+00
#
#             test_id
# count  3.460725e+06
# mean   1.730362e+06
# std    9.990254e+05
# min    0.000000e+00
# 25%    8.651810e+05
# 50%    1.730362e+06
# 75%    2.595543e+06
# max    3.460724e+06

# %%
from selenium import webdriver
from time import sleep
import numpy as np
import requests
from bs4 import BeautifulSoup
import lxml.html
import re
import csv
import pandas as pd

# %%
driver = webdriver.Chrome(r'C:\Users\okefu\merukari_work\chromedriver')

# %%
driver.maximize_window()

# %%
driver.get('https://www.mercari.com/jp/mypage/')

# %%
element = driver.find_element_by_link_text("売上・振込申請")
element.click()

# %%
element = driver.find_element_by_link_text("売上履歴")
element.click()

# %%
def case_tag(text):
    global tag
    global products
    global earnings
    global fees
    global deliverys
    global profits
    global dates
    global ids
    if tag == "fee":
        text = text.replace("¥", "").replace(",","")
        fees.append(int(text))
    if tag == "delivery":
        text = text.replace("¥", "").replace(",","")
        deliverys.append(int(text))
    if tag == "profit":
        text = text.replace("¥", "").replace(",","")
        profits.append(int(text))
    if tag == "date":
        dates.append(text)
    if tag == "id":
        ids.append(text)
    if tag == "product":
        split_list = text.splitlines()
        products.append(split_list[0])
        text = split_list[1].replace("¥", "").replace(",","")
        earnings.append(int(text))
    tag = "none"
def make_tag(text):
    global tag
    if text == "商品":
        tag = "product"
    if text == "販売手数料":
        tag = "fee"
    if text == "配送料":
        tag = "delivery"
    if text == "販売利益":
        tag = "profit"
    if text == "購入日時":
        tag = "date"
    if text == "商品ID":
        tag = "id"

# %%
products = []
earnings = []
fees = []
deliverys = []
profits = []
dates = []
ids = []
blank = []
elem_a = driver.find_elements_by_xpath('/html/body/div[1]/main/div[1]/section/ul/li/a')
for i in range(len(elem_a)):
    elem_a = driver.find_elements_by_xpath('/html/body/div[1]/main/div[1]/section/ul/li/a')
    elem_a[i].click()
    for info in driver.find_elements_by_class_name('transact-info-table-cell'):
        print(info.text)
        #tagで判断
        case_tag(info.text)
        #tagをつける
        make_tag(info.text)
    if len(deliverys) != len(products):
        deliverys.append(0)
    blank.append("")
    driver.back()
# Out:
# 商品
# Cable Matters USB LAN変換アダプター 有線LANアダプター
# ¥800
# 送料
# 送料込み(出品者負担)
# 販売手数料
# ¥80
# 配送料
# ¥175
# 販売利益
# ¥545
# 購入日時
# 8月14日 12:52
# 商品ID
# m66027616476
# 商品
# 犬の服
# ¥800
# 送料
# 送料込み(出品者負担)
# 販売手数料
# ¥80
# 配送料
# ¥175
# 販売利益
# ¥545
# 購入日時
# 6月15日 23:06
# 商品ID
# m43353751584
# 商品
# 犬の帽子
# ¥500
# 送料
# 送料込み(出品者負担)
# 販売手数料
# ¥50
# 配送料
# ¥175
# 販売利益
# ¥275
# 購入日時
# 4月19日 15:40
# 商品ID
# m25609596636
# 商品
# デッドバイデイライト
# ¥3,800
# 送料
# 送料込み(出品者負担)
# 販売手数料
# ¥380
# 配送料
# ¥175
# 販売利益
# ¥3,245
# 購入日時
# 3月25日 11:55
# 商品ID
# m43215848996
# 商品
# 遊戯王 堕天使の追放
# ¥777
# 送料
# 送料込み(出品者負担)
# 販売手数料
# ¥77
# 販売利益
# ¥700
# 購入日時
# 3月26日 16:04
# 商品ID
# m47600513692
# 商品
# 遊戯王 RRフォースストリクス スーパー
# ¥444
# 送料
# 送料込み(出品者負担)
# 販売手数料
# ¥44
# 販売利益
# ¥400
# 購入日時
# 3月22日 20:10
# 商品ID
# m50245164235
# 商品
# 遊戯王 銀河眼の光波竜
# ¥777
# 送料
# 送料込み(出品者負担)
# 販売手数料
# ¥77
# 販売利益
# ¥700
# 購入日時
# 3月23日 01:49
# 商品ID
# m82150072924
# 商品
# 遊戯王 やぶ蛇
# ¥444
# 送料
# 送料込み(出品者負担)
# 販売手数料
# ¥44
# 販売利益
# ¥400
# 購入日時
# 3月23日 20:03
# 商品ID
# m10321158010
# 商品
# 遊戯王 幻想の黒魔導師
# ¥333
# 送料
# 送料込み(出品者負担)
# 販売手数料
# ¥33
# 販売利益
# ¥300
# 購入日時
# 3月22日 18:04
# 商品ID
# m79865238702
# 商品
# 遊戯王 セキュリティドラゴン
# ¥433
# 送料
# 送料込み(出品者負担)
# 販売手数料
# ¥43
# 配送料
# ¥175
# 販売利益
# ¥215
# 購入日時
# 3月23日 17:54
# 商品ID
# m53220152678
# 商品
# 遊戯王 轟雷帝ザボルグ
# ¥777
# 送料
# 送料込み(出品者負担)
# 販売手数料
# ¥77
# 販売利益
# ¥700
# 購入日時
# 3月18日 12:57
# 商品ID
# m33905926739
# 商品
# 遊戯王 ディバインガイ デステニードロー
# ¥666
# 送料
# 送料込み(出品者負担)
# 販売手数料
# ¥66
# 販売利益
# ¥600
# 購入日時
# 3月18日 18:17
# 商品ID
# m14529596643

# %%
print(products)
print(earnings)
print(fees)
print(deliverys)
print(profits)
print(dates)
print(ids)
print(blank)
# Out:
# ['Cable Matters USB LAN変換アダプター 有線LANアダプター', '犬の服', '犬の帽子', 'デッドバイデイライト', '遊戯王 堕天使の追放', '遊戯王 RRフォースストリクス スーパー', '遊戯王 銀河眼の光波竜', '遊戯王 やぶ蛇', '遊戯王 幻想の黒魔導師', '遊戯王 セキュリティドラゴン', '遊戯王 轟雷帝ザボルグ', '遊戯王 ディバインガイ デステニードロー']
# [800, 800, 500, 3800, 777, 444, 777, 444, 333, 433, 777, 666]
# [80, 80, 50, 380, 77, 44, 77, 44, 33, 43, 77, 66]
# [175, 175, 175, 175, 0, 0, 0, 0, 0, 175, 0, 0]
# [545, 545, 275, 3245, 700, 400, 700, 400, 300, 215, 700, 600]
# ['8月14日 12:52', '6月15日 23:06', '4月19日 15:40', '3月25日 11:55', '3月26日 16:04', '3月22日 20:10', '3月23日 01:49', '3月23日 20:03', '3月22日 18:04', '3月23日 17:54', '3月18日 12:57', '3月18日 18:17']
# ['m66027616476', 'm43353751584', 'm25609596636', 'm43215848996', 'm47600513692', 'm50245164235', 'm82150072924', 'm10321158010', 'm79865238702', 'm53220152678', 'm33905926739', 'm14529596643']
# ['', '', '', '', '', '', '', '', '', '', '', '']

# %%
def python_list_add(in1, in2):
    wrk = np.array(in1, dtype=object) + np.array(in2, dtype=object)
    return wrk.tolist()

# %%
mf = python_list_add(fees, deliverys)
print(mf)
# Out:
# [255, 255, 225, 555, 77, 44, 77, 44, 33, 218, 77, 66]

# %%
df = pd.DataFrame({'日付': dates,
                   'メルカリ商品ID': ids,
                   'タイトル': products,
                   '売上': earnings,
                   '手数料': fees,
                   '送料（メルカリ便）': deliverys,
                   'MF転記手数料総額': mf,
                   '送料（出品者負担）': blank,
                   '入金': profits})
print(df)
# Out:
#              日付      メルカリ商品ID                                     タイトル    売上  \
# 0   8月14日 12:52  m66027616476  Cable Matters USB LAN変換アダプター 有線LANアダプター   800
# 1   6月15日 23:06  m43353751584                                      犬の服   800
# 2   4月19日 15:40  m25609596636                                     犬の帽子   500
# 3   3月25日 11:55  m43215848996                               デッドバイデイライト  3800
# 4   3月26日 16:04  m47600513692                               遊戯王 堕天使の追放   777
# 5   3月22日 20:10  m50245164235                     遊戯王 RRフォースストリクス スーパー   444
# 6   3月23日 01:49  m82150072924                              遊戯王 銀河眼の光波竜   777
# 7   3月23日 20:03  m10321158010                                  遊戯王 やぶ蛇   444
# 8   3月22日 18:04  m79865238702                              遊戯王 幻想の黒魔導師   333
# 9   3月23日 17:54  m53220152678                           遊戯王 セキュリティドラゴン   433
# 10  3月18日 12:57  m33905926739                              遊戯王 轟雷帝ザボルグ   777
# 11  3月18日 18:17  m14529596643                     遊戯王 ディバインガイ デステニードロー   666
#
#     手数料  送料（メルカリ便）  MF転記手数料総額 送料（出品者負担）    入金
# 0    80        175        255             545
# 1    80        175        255             545
# 2    50        175        225             275
# 3   380        175        555            3245
# 4    77          0         77             700
# 5    44          0         44             400
# 6    77          0         77             700
# 7    44          0         44             400
# 8    33          0         33             300
# 9    43        175        218             215
# 10   77          0         77             700
# 11   66          0         66             600

# %%
df.head(8)
# Out:
#             日付      メルカリ商品ID                                     タイトル    売上  \
# 0  8月14日 12:52  m66027616476  Cable Matters USB LAN変換アダプター 有線LANアダプター   800
# 1  6月15日 23:06  m43353751584                                      犬の服   800
# 2  4月19日 15:40  m25609596636                                     犬の帽子   500
# 3  3月25日 11:55  m43215848996                               デッドバイデイライト  3800
# 4  3月26日 16:04  m47600513692                               遊戯王 堕天使の追放   777
# 5  3月22日 20:10  m50245164235                     遊戯王 RRフォースストリクス スーパー   444
# 6  3月23日 01:49  m82150072924                              遊戯王 銀河眼の光波竜   777
# 7  3月23日 20:03  m10321158010                                  遊戯王 やぶ蛇   444
#
#    手数料  送料（メルカリ便）  MF転記手数料総額 送料（出品者負担）    入金
# 0   80        175        255             545
# 1   80        175        255             545
# 2   50        175        225             275
# 3  380        175        555            3245
# 4   77          0         77             700
# 5   44          0         44             400
# 6   77          0         77             700
# 7   44          0         44             400

# %%
df.to_csv('merukari.csv', encoding='utf_8_sig')

# %%
df = df.astype(({"売上": object}))
df = df.astype(({"手数料": object}))
df = df.astype(({"送料（メルカリ便）": object}))
df = df.astype(({"MF転記手数料総額": object}))
df = df.astype(({"入金": object}))

# %%
import pandas as pd
import gspread
import json
from oauth2client.service_account import ServiceAccountCredentials 

#2つのAPIを記述しないとリフレッシュトークンを3600秒毎に発行し続けなければならない
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']

#認証情報設定
#ダウンロードしたjsonファイル名をクレデンシャル変数に設定（秘密鍵、Pythonファイルから読み込みしやすい位置に置く）
credentials = ServiceAccountCredentials.from_json_keyfile_name(r'C:\Users\okefu\Downloads\shining-relic-307314-ef4ad4a33ab7.json', scope)

#OAuth2の資格情報を使用してGoogle APIにログインします。
gc = gspread.authorize(credentials)

#共有設定したスプレッドシートキーを変数[SPREADSHEET_KEY]に格納する。
SPREADSHEET_KEY = '1hT6pS7Yp8p346KyX2yFxcXzgL5PqjWH9qBY_8P02SAw'

#共有設定したスプレッドシートのワークシート1を開く
worksheet = gc.open_by_key(SPREADSHEET_KEY).sheet1

# %%
# 数字からアルファベットを返す関数
# 例：26→Z、27→AA、10000→NTP
def toAlpha(num):
    if num<=26:
        return chr(64+num)
    elif num%26==0:
        return toAlpha(num//26-1)+chr(90)
    else:
        return toAlpha(num//26)+chr(64+num%26)

col_lastnum = len(df.columns) # DataFrameの列数
row_lastnum = len(df.index)   # DataFrameの行数

cell_list = worksheet.range('A1:'+toAlpha(col_lastnum)+str(row_lastnum+1))
for cell in cell_list:
    if cell.row == 1:
        val = df.columns[cell.col-1]
    else:
        val = df.iloc[cell.row-2][cell.col-1]
    cell.value = val
worksheet.update_cells(cell_list)
# Out:
# {'spreadsheetId': '1hT6pS7Yp8p346KyX2yFxcXzgL5PqjWH9qBY_8P02SAw',
#  'updatedRange': "'シート1'!A1:I13",
#  'updatedRows': 13,
#  'updatedColumns': 9,
#  'updatedCells': 117}
